# %%
import numpy as np

import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("sodoko.jpg")
img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
corped_num = "crop_folder"

# %%
plt.imshow(img,cmap="gray")

# %%
from PIL import Image
img = Image.open("sodoko.jpg")
box = (40, 40, 580, 570)
img2 = img.crop(box)

# %%
plt.imshow(img2,cmap='gray')

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-113-c60168ace959> in <module>
#       5     for j in range(col):
#       6         box = (i, j, 580, 570)
# ----> 7         img2 = img.crop(box)
#       8         img_result.append(img2)
#       9
#
# c:\users\diana\appdata\local\programs\python\python37\lib\site-packages\PIL\Image.py in crop(self, box)
#    1143
#    1144         self.load()
# -> 1145         return self._new(self._crop(self.im, box))
#    1146
#    1147     def _crop(self, im, box):
#
# c:\users\diana\appdata\local\programs\python\python37\lib\site-packages\PIL\Image.py in _crop(self, im, box)
#    1163         _decompression_bomb_check(absolute_values)
#    1164
# -> 1165         return im.crop((x0, y0, x1, y1))
#    1166
#    1167     def draft(self, mode, size):
#
# MemoryError:

# %%
plt.imshow()

# %%
img1.shape
# Out:
# (606, 601)
