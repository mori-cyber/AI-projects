# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
N =1500
t = np.arange(0,N)

# %%
data_sine = np.sin(0.02*t)/2 + np.random.uniform(-0.05,0.05,N)
plt.figure(figsize=(16,4))
plt.plot(data_sine)
plt.show()

# %%
data_square = np.sign(np.sin(0.02*t))/2 + np.random.uniform(-0.05,0.05,N)
plt.figure(figsize=(16,4))
plt.plot(data_square)
plt.show()

# %%
P=200
A=2
data_tringle = ((A/P)*(P-np.abs(t % (2*P)-P))-1)/2 + np.random.uniform(-0.05,0.05,N)
plt.figure(figsize=(16,4))
plt.plot(data_tringle)
plt.show()

# %%
def convertSignalToDataset(signal,step,label):
  X = []
  Y = []
  for i in range(len(signal)-step):
    j=i + step
    X.append(signal[i:j])
    Y.append(label)
  return np.array(X),np.array(Y)

# %%
X_sine,Y_sine = convertSignalToDataset(data_sine,40,label = 0)
X_square,Y_square = convertSignalToDataset(data_square,40,label = 1)
X_tringle,Y_tringle = convertSignalToDataset(data_tringle,40,label = 2)

# %%
X = np.concatenate((X_sine, X_square,X_tringle), axis=0)
Y = np.concatenate((Y_sine, Y_square,Y_tringle), axis=0)
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (3504, 40)

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
X_train.shape
# Out:
# (3504, 40, 1)

# %%
model = tf.keras.models.Sequential([
                                    layers.SimpleRNN(units=64, input_shape=(None,1)),
                                    layers.Dense(3,activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=100,batch_size=16)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 11s 33ms/step - loss: 0.9333 - accuracy: 0.5300
# Epoch 2/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.7582 - accuracy: 0.6279
# Epoch 3/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.7103 - accuracy: 0.6396
# Epoch 4/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.6303 - accuracy: 0.6712
# Epoch 5/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6675 - accuracy: 0.6715
# Epoch 6/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6597 - accuracy: 0.6635
# Epoch 7/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6807 - accuracy: 0.6590
# Epoch 8/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6433 - accuracy: 0.6892
# Epoch 9/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5986 - accuracy: 0.7058
# Epoch 10/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5899 - accuracy: 0.7152
# Epoch 11/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.6337 - accuracy: 0.7046
# Epoch 12/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5986 - accuracy: 0.7092
# Epoch 13/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5423 - accuracy: 0.7400
# Epoch 14/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5830 - accuracy: 0.7372
# Epoch 15/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5428 - accuracy: 0.7628
# Epoch 16/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4778 - accuracy: 0.7931
# Epoch 17/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6126 - accuracy: 0.7369
# Epoch 18/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4644 - accuracy: 0.8008
# Epoch 19/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4768 - accuracy: 0.8011
# Epoch 20/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4228 - accuracy: 0.8188
# Epoch 21/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3937 - accuracy: 0.8330
# Epoch 22/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3579 - accuracy: 0.8496
# Epoch 23/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3918 - accuracy: 0.8262
# Epoch 24/100
# 219/219 [==============================] - 5s 22ms/step - loss: 0.3862 - accuracy: 0.8439
# Epoch 25/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3709 - accuracy: 0.8345
# Epoch 26/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3426 - accuracy: 0.8542
# Epoch 27/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3412 - accuracy: 0.8559
# Epoch 28/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3147 - accuracy: 0.8724
# Epoch 29/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2654 - accuracy: 0.8901
# Epoch 30/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3927 - accuracy: 0.8379
# Epoch 31/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2764 - accuracy: 0.8887
# Epoch 32/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2437 - accuracy: 0.9004
# Epoch 33/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2819 - accuracy: 0.8878
# Epoch 34/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2685 - accuracy: 0.8847
# Epoch 35/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3388 - accuracy: 0.8579
# Epoch 36/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2497 - accuracy: 0.8998
# Epoch 37/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2643 - accuracy: 0.8993
# Epoch 38/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2982 - accuracy: 0.8821
# Epoch 39/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.1862 - accuracy: 0.9278
# Epoch 40/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2905 - accuracy: 0.8878
# Epoch 41/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2576 - accuracy: 0.8998
# Epoch 42/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3020 - accuracy: 0.8836
# Epoch 43/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2271 - accuracy: 0.9144
# Epoch 44/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.1801 - accuracy: 0.9301
# Epoch 45/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2103 - accuracy: 0.9172
# Epoch 46/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2338 - accuracy: 0.9047
# Epoch 47/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2511 - accuracy: 0.8970
# Epoch 48/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.1974 - accuracy: 0.9269
# Epoch 49/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1843 - accuracy: 0.9284
# Epoch 50/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2939 - accuracy: 0.8850
# Epoch 51/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2620 - accuracy: 0.8998
# Epoch 52/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1829 - accuracy: 0.9255
# Epoch 53/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1845 - accuracy: 0.9281
# Epoch 54/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1993 - accuracy: 0.9227
# Epoch 55/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2151 - accuracy: 0.9158
# Epoch 56/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1725 - accuracy: 0.9335
# Epoch 57/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1525 - accuracy: 0.9412
# Epoch 58/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2332 - accuracy: 0.9087
# Epoch 59/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.7409 - accuracy: 0.7180
# Epoch 60/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6478 - accuracy: 0.6924
# Epoch 61/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5657 - accuracy: 0.7523
# Epoch 62/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5559 - accuracy: 0.7463
# Epoch 63/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4906 - accuracy: 0.7851
# Epoch 64/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4209 - accuracy: 0.8193
# Epoch 65/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3368 - accuracy: 0.8593
# Epoch 66/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3853 - accuracy: 0.8339
# Epoch 67/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2921 - accuracy: 0.8853
# Epoch 68/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2853 - accuracy: 0.8824
# Epoch 69/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3204 - accuracy: 0.8653
# Epoch 70/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3015 - accuracy: 0.8784
# Epoch 71/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2733 - accuracy: 0.8841
# Epoch 72/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2851 - accuracy: 0.8801
# Epoch 73/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2892 - accuracy: 0.8750
# Epoch 74/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2673 - accuracy: 0.8853
# Epoch 75/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2890 - accuracy: 0.8827
# Epoch 76/100
# 219/219 [==============================] - 4s 19ms/step - loss: 0.2557 - accuracy: 0.8890
# Epoch 77/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4875 - accuracy: 0.8091
# Epoch 78/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.7447 - accuracy: 0.6544
# Epoch 79/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3282 - accuracy: 0.8584
# Epoch 80/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2831 - accuracy: 0.8810
# Epoch 81/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2454 - accuracy: 0.8950
# Epoch 82/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2062 - accuracy: 0.9175
# Epoch 83/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1967 - accuracy: 0.9138
# Epoch 84/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2913 - accuracy: 0.8824
# Epoch 85/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2631 - accuracy: 0.8918
# Epoch 86/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2044 - accuracy: 0.9252
# Epoch 87/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2090 - accuracy: 0.9115
# Epoch 88/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3953 - accuracy: 0.8348
# Epoch 89/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3165 - accuracy: 0.8707
# Epoch 90/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2167 - accuracy: 0.9141
# Epoch 91/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2170 - accuracy: 0.9124
# Epoch 92/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.1709 - accuracy: 0.9295
# Epoch 93/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2327 - accuracy: 0.9021
# Epoch 94/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2065 - accuracy: 0.9167
# Epoch 95/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2271 - accuracy: 0.9135
# Epoch 96/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3368 - accuracy: 0.8662
# Epoch 97/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2874 - accuracy: 0.8898
# Epoch 98/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4503 - accuracy: 0.8011
# Epoch 99/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3236 - accuracy: 0.8647
# Epoch 100/100
# 219/219 [==============================] - 4s 20ms/step - loss: 0.2791 - accuracy: 0.8836

# %%
model.evaluate(X_test,Y_test)
# Out:
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2618 - accuracy: 0.8927
# [0.2618477940559387, 0.8926940560340881]

# %%
#sin
x = np.sin(0.02*t)/2 + np.random.uniform(-0.05,0.05,N)
x = x.reshape((1,-1,1))
result = model.predict(x)
print(np.argmax(result))

# %%
#square
N =40
t = np.arange(0,N)
x = np.sign(np.sin(0.02*t))/2 + np.random.uniform(-0.05,0.05,N)
y = x.reshape((1,-1,1))
result = model.predict(y)
print(np.argmax(result))

# %%
#trangle
N = 40
P = 200
A = 2
t = np.arange(0, N)
x = ((A/P)*(P-np.abs(t % (2*P)-P))-1)/2 + np.random.uniform(-0.05,0.05,N)
z = x.reshape((1,-1,1))
result = model.predict(z)
print(np.argmax(result))
